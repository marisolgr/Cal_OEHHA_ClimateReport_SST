# %%
# Shore Station program temperature
# for CAL OEHHA
# acquire data, annual means, trends

# %%
import matplotlib as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stat
from sklearn.preprocessing import PolynomialFeatures
from statsmodels.sandbox.regression.predstd import wls_prediction_std
import statsmodels.api as sm
import warnings
warnings.simplefilter('ignore') #filter some warning messages

# %%
iurl = 'https://shorestations.ucsd.edu/plots/'
urls = ['Trinidad_TEMP.csv','PacificGrove_TEMP.csv','SIO_TEMP.csv']
inirow = [31,28,26] # row number of YEAR label (start in 0)
varnam_file = ['TRINIDAD_BAY_SURF_TEMP_C','SURF_TEMP_C','SURF_TEMP_C']
varnam_out = ['Trinidad Bay','Pacific Grove','La Jolla']
colrs=['tab:blue','olive','tab:red']

# %%
def ssp_ameans(url, vname1, vname2,irow):

    # acquire data
    pdt = pd.read_csv(url, header=irow)
    pdt=pdt[~np.isnan(pdt.YEAR)]

    iy = int(pdt.at[0,'YEAR'])
    fy = int(pdt.at[len(pdt)-1,'YEAR'])
    yrs = list()
    sst = list()
    
    a = pdt[vname1]=='18U'
    pdt[vname1][a]=np.nan
    pdt=pdt.astype({vname1: 'float'})

    for yr in range(iy,fy+1):
        tmp = pdt[pdt['YEAR']==yr]
        tmp = tmp[vname1]
        try: 
            t = np.nanmean(tmp)
        except:
            t = np.nan
        sst.append(t)
        yrs.append(yr)
    apdt = pd.DataFrame(data=sst, index=yrs, columns=[vname2])
    return apdt

# %%
# acquire data
for i in range(3):
    tmp = ssp_ameans(iurl+urls[i],varnam_file[i],varnam_out[i],inirow[i])
    if i==0:
        ssp_sst = tmp.copy()
    else:
        ssp_sst = pd.concat([ssp_sst,tmp],axis=1)
ssp_sst = (ssp_sst * 9/5) + 32

# %%
# select max year to keep
myr=2020
ssp_sst = ssp_sst[ssp_sst.index<=myr]
ssp_sst
# Out:
#       Trinidad Bay  Pacific Grove   La Jolla
# 1916           NaN            NaN  60.155273
# 1917           NaN            NaN  62.136887
# 1918           NaN            NaN  63.293204
# 1919           NaN      54.924984  62.258058
# 1920           NaN      54.598692  61.837119
# ...            ...            ...        ...
# 2016     54.747500      57.035738  65.602264
# 2017     52.937558      56.406319  65.463854
# 2018     52.562819      56.850849  66.348645
# 2019     53.268333      56.953425  65.627115
# 2020     52.675050      56.566557  65.205398
#
# [105 rows x 3 columns]

# %%
plt.figure(figsize=(7,4), dpi=150)
for i in range(3):
    plt.plot(ssp_sst.index,ssp_sst[varnam_out[i]], 'o-',markersize=5, label=varnam_out[i],c=colrs[i],lw=2)
plt.legend(loc=3)
plt.ylim([45,70])
plt.grid(True)
plt.ylabel('Surface Temperature (°F)')
plt.savefig('SSP_TimeSeries_1982-2020.png')
plt.show()

# %%
def calculate_trend(x,y,iy,fy):
    # first degree polynomial
    polf = PolynomialFeatures(1)
    # select years
    a = (x>=iy) & (x<=fy)
    x = x[a]
    y = y[a]
    
    # get rid of nan years
    a = ~np.isnan(y)
    y2=y[a]
    x2=x[a]
    y2 = y2.reshape(-1, 1)
    x2 = x2.reshape(-1, 1)

    # calculate years
    xp = polf.fit_transform(x2)
    mods2 = sm.OLS(y2,xp).fit()
    trend = mods2.params[1]*10
    p_tr = mods2.pvalues[1]

    return trend, p_tr, x2[0][0], x2[-1][0]

# %%
# lenght of time series trend
for i in range(3):
    y = ssp_sst[varnam_out[i]].values
    x = ssp_sst.index.values
    trend, p_tr, iy, fy = calculate_trend(x,y,x[0],x[-1])
    print(varnam_out[i])
    print(trend, p_tr, iy,fy)
# Out:
# Trinidad Bay
# 0.33319759024840456 0.00655599344906327 1973 2020
# Pacific Grove
# 0.18501963130974783 4.951607624549687e-07 1919 2020
# La Jolla
# 0.27717029121265163 1.5127160529635948e-10 1916 2020

# %%
# for the previous report (2016)
for i in range(3):
    y = ssp_sst[varnam_out[i]].values
    x = ssp_sst.index.values
    trend, p_tr, iy, fy = calculate_trend(x,y,1916,2016)
    print(varnam_out[i])
    print(trend, p_tr, iy,fy)
# Out:
# Trinidad Bay
# 0.4329967537363011 0.0026318652079682144 1973 2016
# Pacific Grove
# 0.1835726941434746 3.488475858589307e-06 1919 2016
# La Jolla
# 0.24830941288323 2.630790215891886e-08 1916 2016

# %%
# for the 1982-2020 common period with satellite coastal
for i in range(3):
    y = ssp_sst[varnam_out[i]].values
    x = ssp_sst.index.values
    trend, p_tr, iy, fy = calculate_trend(x,y,1982,2020)
    print(varnam_out[i])
    print(trend, p_tr, iy,fy)
# Out:
# Trinidad Bay
# 0.032331986896401155 0.8381552124976284 1982 2020
# Pacific Grove
# 0.04005957097221069 0.7948700906757338 1982 2020
# La Jolla
# 0.4876115467532016 0.005287564398953135 1982 2020

# %%
# for the 1981-2020 common period
for i in range(3):
    y = ssp_sst[varnam_out[i]].values
    x = ssp_sst.index.values
    trend, p_tr, iy, fy = calculate_trend(x,y,1950,2016)
    print(varnam_out[i])
    print(trend, p_tr, iy,fy)
# Out:
# Trinidad Bay
# 0.4329967537363011 0.0026318652079682144 1973 2016
# Pacific Grove
# 0.161322925358926 0.01877217180043057 1950 2016
# La Jolla
# 0.4943513297229024 2.31194559888799e-09 1950 2016

# %%
for i in range(3):
    y = ssp_sst[varnam_out[i]].values
    x = ssp_sst.index.values
    trend, p_tr, iy, fy = calculate_trend(x,y,2000,2016)
    print(varnam_out[i])
    print(trend, p_tr, iy,fy)
# Out:
# Trinidad Bay
# 0.593935671953354 0.3475613557027586 2000 2016
# Pacific Grove
# -0.3065191535512257 0.58023302384382 2000 2016
# La Jolla
# 1.1956597468066743 0.059399861421939586 2000 2016

# %%
ssp_sst.to_csv('ShoreStationProgram_SST_OceanIndicators.csv')
